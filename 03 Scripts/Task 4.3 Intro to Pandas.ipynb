# %% [markdown]
# # Whitney Hardy
# ## Task 4.3 Intro to Pandas

# %% [markdown]
# ### Content List
# #### Import libraires
# #### Make path
# #### Orders
# #### Checking prices of Products- Changed milk and cottage cheese price to be more appropriate
# #### Answer the following questions using relevant commands

# %% [markdown]
# ### Import Libraires

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### make path

# %%
path = r'C:\Users\hardy\10-2025 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\hardy\\10-2025 Instacart Basket Analysis'

# %% [markdown]
# ### Orders

# %%
df = pd.read_csv(r'C:\Users\hardy\10-2025 Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
#print first 5 rows
df.head(5)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ### Products

# %%
df_prods = pd.read_csv(os.path.join(path, '02 data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_prods.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
df_prods.tail(35)
# Out:
#        product_id                                       product_name  \
# 49658       49654                   Teriyaki Sauce, Sesame, Original
# 49659       49655                                        Apple Cider
# 49660       49656                         Masada Kosher Pocket Bread
# 49661       49657                                  Cabernet Tomatoes
# 49662       49658                         Brie with Herbs Foil Wedge
# 49663       49659                            Organic Creamed Coconut
# 49664       49660                        Professionals Sleek Shampoo
# 49665       49661                                              Porto
# 49666       49662                       Bacon Cheddar Pretzel Pieces
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49668       49664                     Lemon Cayenne Drinking Vinegar
# 49669       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49670       49666                      Ginger Snaps Snacking Cookies
# ...

# %% [markdown]
# #### Checking prices of Products- Changed milk and cottage cheese price to be more appropriate

# %%
#check prices
top_50_expensive = df_prods.nlargest(50, 'prices')

# %%
top_50_expensive
# Out:
#        product_id                                       product_name  \
# 33666       33664                              2 % Reduced Fat  Milk
# 21554       21553                   Lowfat 2% Milkfat Cottage Cheese
# 9020         9020                   Boneless Skinless Chicken Thighs
# 19392       19391                          Turkey Breast Tenderloins
# 21468       21467                             Wild Caught Raw Shrimp
# 25580       25579                      Naturally Smoked Trout Fillet
# 40490       40486                                    Chicken Tenders
# 9896         9896                     Uncured Applewood Smoked Bacon
# 14207       14207                                   Angus Roast Beef
# 36577       36573                                     Peppered Bacon
# 39050       39046                            Smok Cured Turkey Bacon
# 41097       41093                           Sugar Free Dry Rub Bacon
# 48343       48339                                      Lobster Tails
# ...

# %%
# Filter for department 16 and select specific columns
df_prods[df_prods['department_id'] == 16][['product_id', 'product_name', 'prices']]
# Out:
#        product_id                                       product_name  prices
# 8               9                  Light Strawberry Blueberry Yogurt     7.0
# 97             98                          2% Yellow American Cheese     4.5
# 116           117                                 Petit Suisse Fruit     3.1
# 120           121                                      Sharp Cheddar     8.1
# 126           127                                         Marscapone     3.5
# ...           ...                                                ...     ...
# 49621       49617  Creamy Mozzarella Sun-Dried Tomato & Basil Fla...    10.2
# 49626       49622                     Original Powder Coffee Creamer    12.0
# 49632       49628                                  Yoghurt Blueberry    14.7
# 49648       49644                                      Feta Crumbles     6.5
# 49662       49658                         Brie with Herbs Foil Wedge     3.9
#
# [3449 rows x 3 columns]

# %%
# Change price for product_id 33664 (2% Reduced Fat Milk)
df_prods.loc[df_prods['product_id'] == 33664, 'prices'] = 9.99

# %%
# Change price for product_id 21553 (Lowfat 2% Milkfat Cottage Cheese)
df_prods.loc[df_prods['product_id'] == 21553, 'prices'] = 14.90

# %%
# Verify the changes
df_prods[df_prods['product_id'].isin([33664, 21553])][['product_id', 'product_name', 'prices']]
# Out:
#        product_id                      product_name  prices
# 21554       21553  Lowfat 2% Milkfat Cottage Cheese   14.90
# 33666       33664             2 % Reduced Fat  Milk    9.99

# %% [markdown]
# #### Returning back to task steps

# %%
#Print the names of the columns in the df_prods dataframe 
df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
#print number of rows and columns 
df_prods.shape
# Out:
# (49693, 5)

# %% [markdown]
# #### Answer the following questions using relevant commands

# %%
# What's the maximum value of the “aisle_id” column?
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      7.682460
# std    14343.717401     38.316774       5.850282      4.200295
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000     25.000000

# %% [markdown]
# The max value of the aisle_id column is 134

# %%
#What’s the data type of the “department_id” column?
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# Depanrtment_id is an integer data type.
