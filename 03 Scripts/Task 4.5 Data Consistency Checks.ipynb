# %% [markdown]
# # Whitney Hardy
# ## Task 4.5 Data Consistency Checks

# %% [markdown]
# ### Content list
# - Importing libraires
# - Import Data
# - Exercise 4.5 following reading
# - Steps 2-10
# - Export

# %% [markdown]
# ### Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# create a path 
path = r'C:\Users\hardy\10-2025 Instacart Basket Analysis'

# %%
#check output
path
# Out:
# 'C:\\Users\\hardy\\10-2025 Instacart Basket Analysis'

# %% [markdown]
# ### Import Data

# %%
#import orders data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
#import produce data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'prods_wrangled.csv'), index_col = False)

# %%
#check ords
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
#check prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ### Exercise 4.5 following reading

# %%
# create a dataframe
df_test= pd.DataFrame()

# %%
#create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix
# C:\Users\hardy\AppData\Local\Temp\ipykernel_13944\2671172800.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
#finding mixing values
df_prods.isnull().sum()
# Out:
# Unnamed: 0        0
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#create a subset of dataframe to view 16 missing values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        Unnamed: 0  product_id product_name  aisle_id  department_id  prices
# 33             33          34          NaN       121             14    12.2
# 68             68          69          NaN        26              7    11.8
# 115           115         116          NaN        93              3    10.8
# 261           261         262          NaN       110             13    12.1
# 525           525         525          NaN       109             11     1.2
# 1511         1511        1511          NaN        84             16    14.3
# 1780         1780        1780          NaN       126             11    12.3
# 2240         2240        2240          NaN        52              1    14.2
# 2586         2586        2586          NaN       104             13    12.4
# 3159         3159        3159          NaN       126             11    13.1
# 3230         3230        3230          NaN       120             16    14.4
# ...

# %%
# compare the number of rows in your current dataframe with the number in your subset once the missing rows have been removed
df_prods.shape
# Out:
# (49693, 6)

# %%
#create new dataframe with cleaned items
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
#check  output
df_prods_clean.shape
# Out:
# (49677, 6)

# %%
# looking for duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
#checking output
df_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, product_id, product_name, aisle_id, department_id, prices]
# Index: []

# %%
df_prods_clean.shape
# Out:
# (49677, 6)

# %%
#create new dataframe without duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49677, 6)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#finding mixing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
#create a subset of dataframe to view 16 missing values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
# compare the number of rows in your current dataframe with the number in your subset once the missing rows have been removed
df_prods.shape
# Out:
# (49693, 5)

# %%
# create new dataframe (clean) without missing data
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# looking for duplicates
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#create new dataframe without duplicates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
#checking most expensive items
top_10_expensive = df_prods_clean_no_dups.nlargest(10, 'prices')

# %%
#view results
top_10_expensive
# Out:
#        product_id                      product_name  aisle_id  department_id  \
# 33666       33664             2 % Reduced Fat  Milk        84             16
# 21554       21553  Lowfat 2% Milkfat Cottage Cheese       108             16
# 9020         9020  Boneless Skinless Chicken Thighs        35             12
# 19392       19391         Turkey Breast Tenderloins        49             12
# 21468       21467            Wild Caught Raw Shrimp        15             12
# 25580       25579     Naturally Smoked Trout Fillet        15             12
# 40490       40486                   Chicken Tenders        49             12
# 9896         9896    Uncured Applewood Smoked Bacon       106             12
# 14207       14207                  Angus Roast Beef         7             12
# 36577       36573                    Peppered Bacon       106             12
#
#         prices
# 33666  99999.0
# 21554  14900.0
# 9020      25.0
# 19392     25.0
# 21468     25.0
# 25580     25.0
# ...

# %%
#drop top two items
top_10_expensive = top_10_expensive.iloc[2:]

# %%
#check
top_10_expensive
# Out:
#        product_id                    product_name  aisle_id  department_id  \
# 21468       21467          Wild Caught Raw Shrimp        15             12
# 25580       25579   Naturally Smoked Trout Fillet        15             12
# 40490       40486                 Chicken Tenders        49             12
# 9896         9896  Uncured Applewood Smoked Bacon       106             12
# 14207       14207                Angus Roast Beef         7             12
# 36577       36573                  Peppered Bacon       106             12
#
#        prices
# 21468    25.0
# 25580    25.0
# 40490    25.0
# 9896     24.9
# 14207    24.9
# 36577    24.9

# %%
# Remove rows where product_id matches the deleted items
df_prods_clean_no_dups = df_prods_clean_no_dups[~df_prods_clean_no_dups['product_id'].isin([33664, 21553])]

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# export new data file
df_prods_clean_no_dups.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# ### Steps 2-10

# %%
# reviewing orders dataframe 
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# I am noticing 0 number of days in the days_since_prior_order and that feels like possible dupilcated records or missing data.

# %%
# step 3-checking df for mixed-type columns 
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != type(df_test[col].iloc[0])).any(axis=1)
  if len(df_test[weird]) > 0:
    print(col)
# Out:
# mix
# C:\Users\hardy\AppData\Local\Temp\ipykernel_13944\2280987668.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_test[[col]].applymap(type) != type(df_test[col].iloc[0])).any(axis=1)

# %% [markdown]
# I am not seeing any mixed type data in dataframe.

# %%
#checing data types of all colums in the orders df
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(6)
# memory usage: 182.7 MB

# %%
#step 5- run a check for missing values
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# Step 5- days_since_prior_order has 2062009 missing values I made a subset of the rows with values missing from days_since_prior_order to further investigate missing values

# %%
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_ords_nan
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 11               11   2168274        2             1                   2
# 26               26   1374495        3             1                   1
# 39               39   3343014        4             1                   6
# 45               45   2717275        5             1                   3
# ...             ...       ...      ...           ...                 ...
# 3420930     3420930    969311   206205             1                   4
# 3420934     3420934   3189322   206206             1                   3
# 3421002     3421002   2166133   206207             1                   6
# 3421019     3421019   2227043   206208             1                   1
# 3421069     3421069   3154581   206209             1                   3
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
#step 6-
#checking to see if all nan values in days_since_prior_order is equal to 1st time orders from a customer
df_ords_nan['order_number'].value_counts()
# Out:
# order_number
# 1    206209
# Name: count, dtype: int64

# %% [markdown]
# This confirms that all nan values under days_since_prior_order are the customers first order with instacart they can not be deleted. The best course of action would be to make a new variable that acts as a flag to indicate all first time customers.

# %%
#making new flag for first time customers
df_ords['first_order'] = df_ords['days_since_prior_order'].isna()

# %%
#checking 
df_ords
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order  first_order
# ...

# %%
#Step 7 check for duplicates
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, first_order]
# Index: []

# %% [markdown]
# ### Export

# %%
#updating name to keep organized
df_ords_clean = df_ords

# %%
df_ords_clean
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 1   2398795        1             2                   3
# 2                 2    473747        1             3                   3
# 3                 3   2254736        1             4                   4
# 4                 4    431534        1             5                   4
# ...             ...       ...      ...           ...                 ...
# 3421078     3421078   2266710   206209            10                   5
# 3421079     3421079   1854736   206209            11                   4
# 3421080     3421080    626363   206209            12                   1
# 3421081     3421081   2977660   206209            13                   1
# 3421082     3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order  first_order
# ...

# %%
#export 
df_ords_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'))
