# %% [markdown]
# # Whitney Hady

# %% [markdown]
# ### Content list
#
# - Import libraries
# - Import data
# - Merging data
# - Export Data

# %% [markdown]
# #### Import libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Import data

# %%
# Create path
path = r'C:\Users\hardy\10-2025 Instacart Basket Analysis'

# %%
# Import dataframes
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
#checking outputs
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order
# 0                   2                  8                     NaN         True
# 1                   3                  7                    15.0        False
# 2                   3                 12                    21.0        False
# 3                   4                  7                    29.0        False
# 4                   4                 15                    28.0        False

# %%
#check output
df_ords.shape
# Out:
# (3421083, 9)

# %%
#Import dataframes
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
#checking outputs
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#check output
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#check output
df_ords.shape
# Out:
# (3421083, 9)

# %%
df_ords = df_ords.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# #### Merging data

# %%
#merging data- 
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#checking output
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# 1       14084                  2          0   both
# 2       12427                  3          0   both
# 3       26088                  4          0   both
# 4       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large = df_ords.merge(df_ords_prior, on='order_id', how='outer', indicator=True)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only       206209
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large.shape
# Out:
# (32640698, 13)

# %%
df_merged_large.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0       1868044     1868044         1   112108             4
# 1       3355525     3355525         2   202279             3
# 2       3355525     3355525         2   202279             3
# 3       3355525     3355525         2   202279             3
# 4       3355525     3355525         2   202279             3
# 5       3355525     3355525         2   202279             3
# 6       3355525     3355525         2   202279             3
# 7       3355525     3355525         2   202279             3
# 8       3355525     3355525         2   202279             3
# 9       3355525     3355525         2   202279             3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   4                 10                     9.0        False
# 1                   5                  9                     8.0        False
# 2                   5                  9                     8.0        False
# 3                   5                  9                     8.0        False
# 4                   5                  9                     8.0        False
# 5                   5                  9                     8.0        False
# 6                   5                  9                     8.0        False
# 7                   5                  9                     8.0        False
# 8                   5                  9                     8.0        False
# 9                   5                  9                     8.0        False
#
#    product_id  add_to_cart_order  reordered     _merge
# 0         NaN                NaN        NaN  left_only
# 1     33120.0                1.0        1.0       both
# 2     28985.0                2.0        1.0       both
# 3      9327.0                3.0        0.0       both
# 4     45918.0                4.0        1.0       both
# 5     30035.0                5.0        0.0       both
# 6     17794.0                6.0        1.0       both
# 7     40141.0                7.0        1.0       both
# 8      1819.0                8.0        1.0       both
# 9     43668.0                9.0        0.0       both

# %%
#merging data- 
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
#testing output 
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# 1       14084                  2          0   both
# 2       12427                  3          0   both
# 3       26088                  4          0   both
# 4       26405                  5          0   both

# %% [markdown]
# #### Export data

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
