# %% [markdown]
# # Whitney Hardy

# %% [markdown]
# ## Content list
# - Import libraries
# - Import data
# - Merge data
# - Clean merged data
# - Export data

# %% [markdown]
# #### Import libraries

# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Import data

# %%
#create a path
path = r'C:\Users\hardy\10-2025 Instacart Basket Analysis'

# %%
#check path 
path
# Out:
# 'C:\\Users\\hardy\\10-2025 Instacart Basket Analysis'

# %%
#importing orders_products_combined dataframe
orders_products_combined = pd.read_pickle(os.path.join(path, '02 data' , 'prepared data' , 'orders_products_combined.pkl'))

# %%
#check shape
orders_products_combined.shape
# Out:
# (32434489, 13)

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0         196                  1          0   both
# 1       14084                  2          0   both
# 2       12427                  3          0   both
# 3       26088                  4          0   both
# 4       26405                  5          0   both

# %%
#importings products dataframe
df_prods = pd.read_csv(os.path.join(path, '02 data' , 'prepared data' , 'products_checked.csv'), index_col = 0)

# %%
#checking shape
df_prods.shape
# Out:
# (49670, 5)

# %%
#check
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# #### Merge data

# %%
#testing merge
ords_prods_merge = orders_products_combined.merge(df_prods, on = ['product_id'], indicator = 'Match')

# %%
#check output 
ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  first_order  \
# 0                   2                  8                     NaN         True
# 1                   2                  8                     NaN         True
# 2                   2                  8                     NaN         True
# 3                   2                  8                     NaN         True
# 4                   2                  8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge  \
# 0         196                  1          0   both
# 1       14084                  2          0   both
# 2       12427                  3          0   both
# 3       26088                  4          0   both
# 4       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   Match
# 0  both
# 1  both
# 2  both
# 3  both
# 4  both

# %%
# drop the flag column '_merge' from the previous merge
ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32399727       3421081     3421081   2977660   206209            13
# 32399728       3421081     3421081   2977660   206209            13
# 32399729       3421081     3421081   2977660   206209            13
# 32399730       3421081     3421081   2977660   206209            13
# 32399731       3421081     3421081   2977660   206209            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# 1                          2                  8                     NaN
# 2                          2                  8                     NaN
# 3                          2                  8                     NaN
# 4                          2                  8                     NaN
# ...                      ...                ...                     ...
# 32399727                   1                 12                     7.0
# 32399728                   1                 12                     7.0
# 32399729                   1                 12                     7.0
# 32399730                   1                 12                     7.0
# 32399731                   1                 12                     7.0
#
#           first_order  product_id  add_to_cart_order  reordered  \
# 0                True         196                  1          0
# 1                True       14084                  2          0
# 2                True       12427                  3          0
# 3                True       26088                  4          0
# 4                True       26405                  5          0
# ...               ...         ...                ...        ...
# 32399727        False       14197                  5          1
# 32399728        False       38730                  6          0
# 32399729        False       31477                  7          0
# 32399730        False        6567                  8          0
# 32399731        False       22920                  9          0
#
#                                      product_name  aisle_id  department_id  \
# 0                                            Soda        77              7
# 1         Organic Unsweetened Vanilla Almond Milk        91             16
# 2                             Original Beef Jerky        23             19
# 3                      Aged White Cheddar Popcorn        23             19
# 4                XL Pick-A-Size Paper Towel Rolls        54             17
# ...                                           ...       ...            ...
# 32399727                             Tomato Paste         9              9
# 32399728          Brownie Crunch High Protein Bar         3             19
# 32399729    High Protein Bar Chunky Peanut Butter         3             19
# 32399730      Chocolate Peanut Butter Protein Bar         3             19
# 32399731      Roasted & Salted Shelled Pistachios       117             19
#
#           prices Match
# 0            9.0  both
# 1           12.5  both
# 2            4.4  both
# 3            4.7  both
# 4            1.0  both
# ...          ...   ...
# 32399727     5.6  both
# 32399728     5.9  both
# 32399729     4.2  both
# 32399730     4.9  both
# 32399731     1.7  both
#
# [32399732 rows x 17 columns]

# %% [markdown]
# #### Clean merged data

# %%
#drop unnamed columns 
ords_prods_merge.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

# %%
#check output 
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge                             product_name  aisle_id  \
# 0          0   both                                     Soda        77
# 1          0   both  Organic Unsweetened Vanilla Almond Milk        91
# 2          0   both                      Original Beef Jerky        23
# 3          0   both               Aged White Cheddar Popcorn        23
# 4          0   both         XL Pick-A-Size Paper Towel Rolls        54
#
#    department_id  prices Match
# 0              7     9.0  both
# 1             16    12.5  both
# 2             19     4.4  both
# 3             19     4.7  both
# 4             17     1.0  both

# %%
# chek the shape 
ords_prods_merge.shape
# Out:
# (32399732, 16)

# %%
#check results using merge flag
ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32399732
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### Export data

# %%
#export merged dataframe
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))
